# %% [markdown]
# <a href="https://colab.research.google.com/github/HYUNMIN-HWANG/Colab/blob/main/OpenCV/OpenCV_3_resize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OpenCV Course
# # Full Tutorial with Python
# link : https://www.youtube.com/watch?v=oXlwWbU8l2o

# %%
from google.colab import drive
drive.mount('./MyDrive')
# Out:
# Mounted at ./MyDrive

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# read image (large size)
img = cv.imread('./MyDrive/MyDrive/Colab/OpenCV/cat_large.jpg')
# display image
plt.imshow(img)

# resize image
def rescaleFrame(frame, scale=0.75) :
    # image, video, live video
    width = int(frame.shape[1] * scale) 
    height = int(frame.shape[0] * scale)
    dimensions = (width, height)
    return cv.resize (frame, dimensions, interpolation=cv.INTER_AREA)
resized_image = rescaleFrame(img)
plt.imshow(resized_image)

def changeRes(width, height) :
    # only live video
    capture.set(3,width)
    capture.set(4,height)

'''
# read videos
capture = cv.VideoCapture('./MyDrive/MyDrive/Colab/OpenCV/dog.mp4')
# display video
while True :
    isTure, frame = capture.read()  # 동영상을 프레임 by 프레임으로 읽는다.

    frame_resized = rescaleFrame(frame, scale=.2)
    
    cv.imshow('Video', frame)
    cv.imshow('Video Resized', frame_resized)
    if cv.waitKey(20) & 0xFF == ord('d'):   # stop video
        break

capture.release()
cv.destroyAllWindows()
'''
# delay
cv.waitKey(0)
# Out:
# -1
